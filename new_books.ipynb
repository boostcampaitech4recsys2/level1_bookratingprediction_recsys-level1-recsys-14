# %%
import pandas as pd

# %%
books = pd.read_csv('new_books.csv')

# %%
books.head(10)
# Out:
#    Unnamed: 0        isbn                                         book_title  \
# 0           0  0002005018                                       Clara Callan
# 1           1  0060973129                               Decision in Normandy
# 2           2  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3           3  0399135782                             The Kitchen God's Wife
# 4           4  0425176428  What If?: The World's Foremost Military Histor...
# 5           5  0671870432                                    PLEADING GUILTY
# 6           6  074322678X            Where You'll Find Me: And Other Stories
# 7           7  0771074670                        Nights Below Station Street
# 8           8  0887841740                                 The Middle Stories
# 9           9  1552041778                                           Jane Doe
#
#           book_author  year_of_publication                 publisher  \
# ...

# %%
aa = [i for i, TF in enumerate(books['summary'].isna()) if TF]
for i in aa:
    books['summary'][i] = books['book_title'][i]
# Out:
# /tmp/ipykernel_111246/3752929015.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books['summary'][i] = books['book_title'][i]

# %%
books.head(10)
# Out:
#          isbn                                         book_title  \
# 0  0002005018                                       Clara Callan
# 1  0060973129                               Decision in Normandy
# 2  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3  0399135782                             The Kitchen God's Wife
# 4  0425176428  What If?: The World's Foremost Military Histor...
# 5  0671870432                                    PLEADING GUILTY
# 6  074322678X            Where You'll Find Me: And Other Stories
# 7  0771074670                        Nights Below Station Street
# 8  0887841740                                 The Middle Stories
# 9  1552041778                                           Jane Doe
#
#           book_author  year_of_publication                 publisher  \
# 0  richardbrucewright               2001.0     HarperFlamingo Canada
# 1         carlod'este               1991.0           HarperPerennial
# ...

# %%
books['summary'].isna().sum()
# Out:
# 0

# %%
# books.loc[books['summary'].isna(), "summary"] = books.book_title # 재형님 코드

# %%
books[['book_title', 'summary']].head(10)
# Out:
#                                           book_title  \
# 0                                       Clara Callan
# 1                               Decision in Normandy
# 2  Flu: The Story of the Great Influenza Pandemic...
# 3                             The Kitchen God's Wife
# 4  What If?: The World's Foremost Military Histor...
# 5                                    PLEADING GUILTY
# 6            Where You'll Find Me: And Other Stories
# 7                        Nights Below Station Street
# 8                                 The Middle Stories
# 9                                           Jane Doe
#
#                                              summary
# 0  In a small town in Canada, Clara Callan reluct...
# 1  Here, for the first time in paperback, is an o...
# 2  Describes the great flu epidemic of 1918, an o...
# 3  A Chinese immigrant who is convinced she is dy...
# 4  Essays by respected military historians, inclu...
# 5                                    PLEADING GUILTY
# ...

# %%
# summary에 특수문자가 &#39;로 표시된 경우 처리
# 개행 문자('\n')을 공백(' ')으로 변경
summary_ = pd.DataFrame(books[['book_title','summary']])

dic = {
    "&quot;" : '"',
    "&amp;" : "&",
    "&lt;" : "<",
    "&gt;" : '>',
    "&#34;" : '"',
    '&#39;' : "'"
}

for k, v in dic.items():
    summary_['summary'] = summary_['summary'].str.replace(k,v, regex=True)
summary_['summary'] = summary_['summary'].str.replace('\n', ' ')
books['summary'] = summary_['summary'].apply(lambda x: x.lower())

for k, v in dic.items():
    summary_['book_title'] = summary_['book_title'].str.replace(k,v, regex=True)
summary_['book_title'] = summary_['book_title'].str.replace('\n', ' ')
books['book_title'] = summary_['book_title'].apply(lambda x: x.lower())

# %%
books[['book_title', 'summary']].head(10)
# Out:
#                                           book_title  \
# 0                                       clara callan
# 1                               decision in normandy
# 2  flu: the story of the great influenza pandemic...
# 3                             the kitchen god's wife
# 4  what if?: the world's foremost military histor...
# 5                                    pleading guilty
# 6            where you'll find me: and other stories
# 7                        nights below station street
# 8                                 the middle stories
# 9                                           jane doe
#
#                                              summary
# 0  in a small town in canada, clara callan reluct...
# 1  here, for the first time in paperback, is an o...
# 2  describes the great flu epidemic of 1918, an o...
# 3  a chinese immigrant who is convinced she is dy...
# 4  essays by respected military historians, inclu...
# 5                                    pleading guilty
# ...

# %%
books.head()
# Out:
#          isbn                                         book_title  \
# 0  0002005018                                       clara callan
# 1  0060973129                               decision in normandy
# 2  0374157065  flu: the story of the great influenza pandemic...
# 3  0399135782                             the kitchen god's wife
# 4  0425176428  what if?: the world's foremost military histor...
#
#           book_author  year_of_publication                 publisher  \
# 0  richardbrucewright               2001.0     HarperFlamingo Canada
# 1         carlod'este               1991.0           HarperPerennial
# 2      ginabarikolata               1999.0      Farrar Straus Giroux
# 3              amytan               1991.0          Putnam Pub Group
# 4        robertcowley               2000.0  Berkley Publishing Group
#
#                                              img_url language   category  \
# 0  http://images.amazon.com/images/P/0002005018.0...       en  actresses
# ...

# %%
books.isna().sum()
# Out:
# isbn                       0
# book_title                 0
# book_author                0
# year_of_publication        0
# publisher                  0
# img_url                    0
# language               25349
# category               68786
# summary                    0
# img_path                   0
# category_low           68786
# dtype: int64

# %%
new_books = pd.read_csv('new_books.csv')
new_books.isna().sum()
# Out:
# Unnamed: 0             0
# isbn                   0
# book_title             0
# book_author            0
# year_of_publication    0
# publisher              0
# img_url                0
# language               0
# category               0
# summary                0
# img_path               0
# dtype: int64

# %%
new_books.head(10)
# Out:
#    Unnamed: 0        isbn                                         book_title  \
# 0           0  0002005018                                       Clara Callan
# 1           1  0060973129                               Decision in Normandy
# 2           2  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3           3  0399135782                             The Kitchen God's Wife
# 4           4  0425176428  What If?: The World's Foremost Military Histor...
# 5           5  0671870432                                    PLEADING GUILTY
# 6           6  074322678X            Where You'll Find Me: And Other Stories
# 7           7  0771074670                        Nights Below Station Street
# 8           8  0887841740                                 The Middle Stories
# 9           9  1552041778                                           Jane Doe
#
#           book_author  year_of_publication                 publisher  \
# ...
